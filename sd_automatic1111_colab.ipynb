# %%
# !nvidia-smi
# !nvcc --version
# Out:
# Wed May  3 19:42:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#@title Cloning automatic1111
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git

# !wget -P /content/stable-diffusion-webui/models/VAE https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt
# !pip install -r /content/stable-diffusion-webui/requirements.txt --quiet
# !pip install triton --quiet
#!pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu117 --quiet
# !git clone https://github.com/Stability-AI/stablediffusion /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai
# %cd /content/stable-diffusion-webui

# cloning the controlnet
# !mkdir /content/stable-diffusion-webui/models/ControlNet
# !wget -P /content/stable-diffusion-webui/models/ControlNet https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth

# cloning deforum
# !git clone https://github.com/Mikubill/sd-webui-controlnet.git /content/stable-diffusion-webui/extensions/sd-webui-controlnet
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum

# downloading the models
# !wget -P /content/stable-diffusion-webui/models/Stable-diffusion https://civitai.com/api/download/models/48174 --content-disposition
# !wget -P /content/stable-diffusion-webui/models/Lora https://civitai.com/api/download/models/55033 --content-disposition
# !wget -P /content/stable-diffusion-webui/models/Lora https://civitai.com/api/download/models/49323 --content-disposition
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 18966, done.
# remote: Counting objects: 100% (560/560), done.
# remote: Compressing objects: 100% (239/239), done.
# remote: Total 18966 (delta 345), reused 484 (delta 321), pack-reused 18406
# Receiving objects: 100% (18966/18966), 28.89 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (13219/13219), done.
# --2023-05-03 19:42:33--  https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt
# Resolving huggingface.co (huggingface.co)... 65.9.86.34, 65.9.86.125, 65.9.86.104, ...
# Connecting to huggingface.co (huggingface.co)|65.9.86.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
#@title Launching automatic1111
# !python ./repositories/stable-diffusion-stability-ai/setup.py build develop
# !python /content/stable-diffusion-webui/launch.py --share
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/test
# copying test/__init__.py -> build/lib/test
# copying test/server_poll.py -> build/lib/test
# creating build/lib/test/basic_features
# copying test/basic_features/img2img_test.py -> build/lib/test/basic_features
# copying test/basic_features/__init__.py -> build/lib/test/basic_features
# copying test/basic_features/extras_test.py -> build/lib/test/basic_features
# copying test/basic_features/txt2img_test.py -> build/lib/test/basic_features
# copying test/basic_features/utils_test.py -> build/lib/test/basic_features
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...
